# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.special import jn,jnp_zeros

# %%
vector1 = np.array([1, 2, 3])
vector2 = np.array([4, 5, 6])
N = 2
v = np.arange(N)
a = 2*np.pi/N*v
print(a)
# Out:
# [0.         3.14159265]

# %%
dot_product = np.multiply(vector1, vector2)
print("Dot Product:", dot_product)
# Out:
# Dot Product: [ 4 10 18]

# %%
class EWM:
    def _init_(self, _delta_frequency):
        self.delta_frequency = _delta_frequency
    
    def set_eta(self, m):
        self.eta = math.log(10)*m*self.delta_frequency
        
    def falling_exp_window(self, vector, time_series):
        exponential_time_series = np.exp(-self.eta*time_series)
        return np.multiply(vector,exponential_time_series)
    
    def rising_exp_window(self, vector, time_series):
        exponential_time_series = np.exp(self.eta*time_series)
        return np.multiply(vector,exponential_time_series)
    
    def FFT(self, signal_TD):
        signal_FD = np.fft.fft(signal_TD)
    
    def IFFT(self, signal_FD):
        signal_TD = np.fft.ifft(signal_FD)
    
    
class SimplifiedModel:
    def __init__(self, _radius, _c, _rho, _strength, _num_terms, _num_modes = 0,  _distance_off_center = 0):
        self.radius = _radius
        # c denote speed of sound in fluid
        self.c = _c
        self.rho = _rho
        self.strength = _strength
        self.num_terms =  _num_terms
        self.num_modes = _num_modes
        self.distance_off_center = _distance_off_center
    def transfer(self, r, theta, z, w):
        if self.distance_off_center == 0:
            # in this case , result independent of theta
            #z denote zeros of the functions J_n'(x)
            n = 0;
            k = jnp_zeros(n,self.num_terms)/self.radius
            k_0 = w/self.c
            sqrt_vec = np.sqrt(k_0*k_0-k*k)
            truncated_series =  np.exp(-j*z*sqrt_vec)/sqrt_vec*jn(n, k*r)/(jn(n, k*self.radius)*jn(n, k*self.radius))
            transfer_function = np.sum(truncated_series)
            return transfer_function
             
        else:
            print(f"The code is not available for off-center ponint souce")
    def displacement_response(self, r, theta, z):
        N = length(self.strength)
        w = 2*np.pi/N*np.arange(N)
        self.displacement = j/(2*np.pi*self.radius*self.radius)*self.transfer(r, theta, z, w)*self.strength
        return displacement
    def pressure_response(self, r, theta, z):
        N = length(self.strength)
        w = 2*np.pi/N*np.arange(N) 
        self.pressure = self.rho/(self.c*self.radius*self.radius)*w*self.transfer(r, theta, z, w)*self.strength

# %%
simpletest = SimplifiedModel(1,2)
simpletest.set_eta(1)
print(simpletest.eta)
# Out:
# 4.605170185988092

# %%
# 设置阶数
n = 0

# 生成一些x值
x = np.linspace(0, 10, 100)
root = jnp_zeros(n,2)
root = jn(n, x)
# 计算第一类贝塞尔函数
y = jn(n, x)
# 绘制图表
print(root)
plt.plot(x, y, label=f'Bessel J{n}(x)')
plt.xlabel('x')
plt.ylabel(f'J{n}(x)')
plt.legend()
plt.show()
# Out:
# [3.83170597]
